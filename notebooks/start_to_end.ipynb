# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('../')))
os.chdir('../')

# %%
from modules.get_region import RetrieveRegion
from modules.pipeline import get_raster_terrain

# %%
ret = RetrieveRegion(bnds=[-93.756155, 41.918015, -93.747334, 41.921429], crs='EPSG:4326')
# Out:
# RetrieveRegion initialized...

# %%
ret_dict = ret.get_region()
# Out:
# Match acquired!

# %%
ret_dict
# Out:
# {'region': 'IA_FullState',
#  'path': 'https://s3-us-west-2.amazonaws.com/usgs-lidar-public/IA_FullState/ept.json',
#  'bounds': [[-10436887.43333523, -10435905.484106943],
#   [5148706.389047224, 5149217.145836504]]}

# %%
(-10435905.484106943 - -10436887.43333523) * (5149217.145836504 - 5148706.389047224)
# Out:
# 501537.2350758105

# %%
f_p = ret_dict['path']
bds = '(' + str(ret_dict['bounds'][0]) + ',' + str(ret_dict['bounds'][1]) + ')'
c_p = 'data/roi.csv'
t_p = 'img/roi.tif'
p_p = 'data/pipeline.txt'

# %%
get_raster_terrain(file_path=f_p ,bounds=bds , csv_path=c_p , tiff_path=t_p, pipeline_path=p_p)

# %%
from modules.visualize import plot_raster_, viz_contour, viz_3d

# %%
viz_contour(tif_path='img/roi.tif', img_path='img/roi.jpg', title='DEM', notebook=True)

# %%
viz_3d(csv_path='data/roi.csv', title='DEM', img_save_path='img/roi3d.jpg')

# %%
plot_raster_(tifile='img/roi.tif', title='DEM', img_save_path='img/roi_ras.jpg', notebook=True)
# Out:
# C:\Users\kaaym\Documents\GitHub\Modeling-Water-Flow-Using-A-Custom-Built-Python-Module\modules\visualize.py:40: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   plt.colorbar(im1, fraction=0.03)

# %%
plot_raster_(tifile='img/twi.tif', title='TWI', img_save_path='img/twi.jpg', notebook=True)
